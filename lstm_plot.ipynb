# %%
import matplotlib.pyplot as plt

# %%
def plot_metriks(data,title):
    names = list(data.keys())
    values = list(data.values())
    plt.title(title)
    plt.bar(range(len(data)), values, tick_label=names)
    plt.savefig(title, dpi=3600)
    plt.show()

# %% [markdown]
# # TIME STEPS

# %% [markdown]
# ## ANTM

# %%
mae_antm = {'timesteps_1':0.05351210758470884,'timesteps_2':0.008161751530795817,'timesteps_3':0.009117184707894537,'timesteps_4':0.008764602393161843}

mape_antm = {'timesteps_1':0.17672596212047678,'timesteps_2':0.036884902423474634,'timesteps_3':0.0415330433575899,'timesteps_4':0.041414121470253945}

rmse_antm = {'timesteps_1':0.1109104112490807,'timesteps_2':0.013446005459325163,'timesteps_3':0.014982986270849675,'timesteps_4':0.014978998319218338}

r2_antm = {'timesteps_1': -0.012847259777391207,'timesteps_2':0.9952483822666641,'timesteps_3':0.9943208018711837,'timesteps_4':0.9943954589232934}

# %%
plot_metriks(mae_antm,"plot mae of tuning parameter timesteps antm")

# %%
plot_metriks(mape_antm,"plot mape of tuning parameter timesteps antm")

# %%
plot_metriks(rmse_antm,"plot rmse of tuning parameter timesteps antm")

# %%
plot_metriks(rmse_antm,"plot rmse of tuning parameter timesteps antm")

# %% [markdown]
# ## ASII

# %%
mae_asii = {'timesteps_1':0.015697579842078434,'timesteps_2':0.015313086808529379,'timesteps_3':0.01468973459169929,'timesteps_4':0.015275431236995839}

mape_asii = {'timesteps_1':0.03516537230185299,'timesteps_2':0.05661475089706797,'timesteps_3':0.0329870319926044,'timesteps_4':0.019597623902703688}

rmse_asii = {'timesteps_1':0.02077293181651314,'timesteps_2':0.020241523730058424,'timesteps_3':0.04428520573595462,'timesteps_4':0.020267971711778642}

r2_asii = {'timesteps_1':0.9891798496508,'timesteps_2':0.9900058330429263,'timesteps_3':0.9901866526074022,'timesteps_4':0.9896423031917067}

# %%
plot_metriks(mae_asii,"plot mae of tuning parameter timesteps asii")

# %%
plot_metriks(mape_asii,"plot mape of tuning parameter timesteps asii")

# %%
plot_metriks(rmse_asii,"plot rmse of tuning parameter timesteps asii")

# %%
plot_metriks(r2_asii,"plot r2 of tuning parameter timesteps asii")

# %% [markdown]
# ## ICBP

# %%
mae_icbp = {'timesteps_1':0.0071951216005588505,'timesteps_2':0.00874996393974662,'timesteps_3':0.009715755021447626,'timesteps_4':0.24760012053707564}

mape_icbp = {'timesteps_1':0.02911766342732286,'timesteps_2':0.10803360291602122,'timesteps_3':0.03398883492185345,'timesteps_4':0.46217821589569885}

rmse_icbp = {'timesteps_1':0.011925892437280167,'timesteps_2':0.011925892437280167,'timesteps_3':0.013880861676693924,'timesteps_4':0.2913636094589231}

r2_icbp = {'timesteps_1':0.9982912893287746,'timesteps_2':0.998219167116058,'timesteps_3':0.9975988977109971,'timesteps_4':0.0}

# %%
plot_metriks(mae_icbp,"plot mae of tuning parameter timesteps icbp")

# %%
plot_metriks(mape_icbp,"plot mape of tuning parameter timesteps icbp")

# %%
plot_metriks(rmse_icbp,"plot rmse of tuning parameter timesteps icbp")

# %%
plot_metriks(r2_icbp,"plot r2 of tuning parameter timesteps icbp")

# %% [markdown]
# ## JSMR

# %%
mae_jsmr = {'timesteps_1':0.012709409360352766,'timesteps_2':0.014326228000078446,'timesteps_3':0.013212442520124074,'timesteps_4':0.012534012823066423}

mape_jsmr = {'timesteps_1':0.030344619679000352,'timesteps_2':0.03485906558726514,'timesteps_3':0.04070394123414279,'timesteps_4':0.029484858211290245}

rmse_jsmr = {'timesteps_1':0.017236430432879077,'timesteps_2':0.018798476996323747,'timesteps_3':0.017914216506633596,'timesteps_4':0.01756805243763662}

r2_jsmr = {'timesteps_1':0.9935702374781473,'timesteps_2':0.9923649299409023,'timesteps_3':0.9929662622837995,'timesteps_4':0.9933026921297792}

# %%
plot_metriks(mae_jsmr,"plot mae of tuning parameter timesteps jsmr")

# %%
plot_metriks(mape_jsmr,"plot mape of tuning parameter timesteps jsmr")

# %%
plot_metriks(rmse_jsmr,"plot rmse of tuning parameter timesteps jsmr")

# %%
plot_metriks(r2_jsmr,"plot r2 of tuning parameter timesteps jsmr")

# %% [markdown]
# # HIDDEN LAYER

# %% [markdown]
# ## ANTM

# %%
mae_antm_hl = {'hidden layer_1':0.008152804872559106,'hidden layer_2':0.013214672773774904,'hidden layer_3':0.009998062981012124,'hidden layer_3':0.008228418334623457}

mape_antm_hl = {'hidden layer_1':0.03489248940375355,'hidden layer_2':0.054800074878532695,'hidden layer_3':0.04404339294199065,'hidden layer_3':0.03492159235018264}

rmse_antm_hl = {'hidden layer_1':0.013849466958302258,'hidden layer_2':0.017459215173058307,'hidden layer_3':0.015687598031636656,'hidden layer_3':}

r2_antm_hl = {'hidden layer_1':0.9949518577972858,'hidden layer_2':0.9924275692637212,'hidden layer_3':0.9940292328244711,'hidden layer_3':0.9949234614902839}

# %%
plot_metriks(mae_antm,"plot mae of tuning parameter hidden layer antm")

# %%
plot_metriks(mape_antm,"plot mape of tuning parameter hidden layer antm")

# %%
plot_metriks(rmse_antm,"plot rmse of tuning parameter hidden layer antm")

# %%
plot_metriks(r2_antm,"plot r2 of tuning parameter hidden layer antm")

# %% [markdown]
# ## ASII

# %%
mae_asii_hl = {'hidden layer_1':0.014757829851888154,'hidden layer_2':0.016830770740112168,'hidden layer_3':0.018521870427194456,'hidden layer_4':0.016859120812902816}

mape_asii_hl = {'hidden layer_1':0.03297773155326224,'hidden layer_2':0.03642616801224726,'hidden layer_3':0.03875453612873989,'hidden layer_4':0.04349796703399346}

rmse_asii_hl = {'hidden layer_1':0.019715849938205837,'hidden layer_2':0.02168610640315832,'hidden layer_3':0.023499048452511002,'hidden layer_4':0.021919565859925376}

r2_asii_hl = {'hidden layer_1':0.9901460537730357,'hidden layer_2':0.988113325668868,'hidden layer_3':0.9867944354102721,'hidden layer_4':0.9868324360049459}

# %%
plot_metriks(mae_asii,"plot mae of tuning parameter hidden layer asii")

# %%
plot_metriks(mape_asii,"plot mape of tuning parameter hidden layer asii")

# %%
plot_metriks(rmse_asii,"plot rmse of tuning parameter hidden layer asii")

# %%
plot_metriks(r2_asii,"plot r2 of tuning parameter hidden layer asii")

# %% [markdown]
# ## ICBP

# %%
mae_icbp_hl = {'hidden layer_1':0.007086988590841109,'hidden layer_2':0.014612323625379744,'hidden layer_3':0.012223985095585319,'hidden layer_4':0.24899680086672094}

mape_icbp_hl = {'hidden layer_1':0.03267820511245089,'hidden layer_2':0.043830805202935724,'hidden layer_3':0.04706924282926418,'hidden layer_4':0.47254809998808467}

rmse_icbp_hl = {'hidden layer_1':0.011508974319469607,'hidden layer_2':0.018640083083157434,'hidden layer_3':0.015606241078365998,'hidden layer_4':0.29000022547373844}

r2_icbp_hl = {'hidden layer_1':0.9983233676202956,'hidden layer_2':0.9958080907798392,'hidden layer_3':0.9969796337720037,'hidden layer_4':-23672082351204.34}

# %%
plot_metriks(mae_icbp,"plot mae of tuning parameter hidden layer icbp")

# %%
plot_metriks(mape_icbp,"plot mape of tuning parameter hidden layer icbp")

# %%
plot_metriks(rmse_icbp,"plot rmse of tuning parameter hidden layer icbp")

# %%
plot_metriks(r2_icbp,"plot r2 of tuning parameter hidden layer icbp")

# %% [markdown]
# ## JSMR

# %%
mae_jsmr_hl = {'hidden layer_1':0.011318812825305483,'hidden layer_2':0.023105861713602516,'hidden layer_3':0.01157825894564719,'hidden layer_4':0.032494819793814744}

mape_jsmr_hl = {'hidden layer_1':0.03565450266272184,'hidden layer_2':0.05353211593323678,'hidden layer_3':0.03242430534782007,'hidden layer_4':0.06866716078656558}

rmse_jsmr_hl = {'hidden layer_1':0.016052783071759058,'hidden layer_2':0.02702812409054237,'hidden layer_3':0.016230213939194986,'hidden layer_4':0.0374025859927203}

r2_jsmr_hl = {'hidden layer_1':0.9943690684509984,'hidden layer_2':0.984495483254619,'hidden layer_3':0.9941938767627192,'hidden layer_4':0.965350130015121}

# %%
plot_metriks(mae_jsmr,"plot mae of tuning parameter hidden layer jsmr")
plot_metriks(mape_icbp,"plot mape of tuning parameter hidden layer icbp")
plot_metriks(rmse_icbp,"plot rmse of tuning parameter hidden layer icbp")
plot_metriks(r2_icbp,"plot r2 of tuning parameter hidden layer icbp")

# %% [markdown]
# # NEURON

# %% [markdown]
# ## ANTM

# %%
mae_antm_hl_u = {'neuron_8':0.007381959033403783,'neuron_n2_h1':0.00823605269281967,'neuron_32':0.007800786881116363}

mape_antm_hl_u = {'neuron_8':0.031562910474329076,'neuron_16':0.03322722405202451,'neuron_32':0.03366333070273749}

rmse_antm_hl_u = {'neuron_8':0.012952183842756504,'neuron_16':0.013418698534813596,'neuron_32':0.01281049725205452}

r2_antm_hl_u = {'neuron_8':0.9956150149776316,'neuron_16':0.9955904992369539,'neuron_32':0.9958286329046172}

# %% [markdown]
# ## ASII

# %%
mae_asii_hl_u = {'neuron_8':0.15513243754641684,'neuron_16':0.017059779115095142,'neuron_32':0.01606562881645174}

mape_asii_hl_u = {'neuron_8':0.26755254397103484,'neuron_16':0.0367542015337045,'neuron_32':0.03518855064266929}

rmse_asii_hl_u = {'neuron_8':0.1987262875601528,'neuron_16':0.021834368279878055,'neuron_32':0.02089426813565111}

r2_asii_hl_u = {'neuron_8':11116048445753.354,'neuron_16':0.988098607751643,'neuron_32':0.9890624663068344}

# %% [markdown]
# ## ICBP

# %%
mae_icbp_hl_u = {'neuron_8':0.007219575749619669,'neuron_16':0.013130016098796896,'neuron_32':0.007642545358463815}

mape_icbp_hl_u = {'neuron_8':0.03275499929793462,'neuron_16':0.04979794569797597,'neuron_32':0.03016892717619271}

rmse_icbp_hl_u = {'neuron_8':0.010855205473752638,'neuron_16':0.016273690008413277,'neuron_32':0.011347603920705211}

r2_icbp_hl_u = {'neuron_8':0.9985081548048771,'neuron_16':0.996696203217586,'neuron_32':0.9983299891561908}

# %% [markdown]
# ## JSMR

# %%
mae_icbp_hl_u = {'neuron_8':0.012040242615234582,'neuron_16':0.013059401724296498,'neuron_32':0.013832471117947474}

mape_icbp_hl_u = {'neuron_8':0.029570296893978765,'neuron_16':0.03211615768041788,'neuron_32':0.03328455771441629}

rmse_icbp_hl_u = {'neuron_8':0.017130419369398783,'neuron_16':0.018129514513005887,'neuron_32':0.018472413116260567}

r2_icbp_hl_u = {'neuron_8':0.9935633197829596,'neuron_16':0.9927780124599436,'neuron_32':0.9927247075638287}

# %% [markdown]
# # Learning rate

# %% [markdown]
# ## ANTM

# %%
mae_antm_hl_u_lr = {'learning_rate_1':0.025849717922488864,'learning_rate_2':0.3295556057475342,'learning_rate_3':0.2997065586539258}

mape_antm_hl_u_lr = {'learning_rate_1':0.6667925415305942,'learning_rate_2':9.923141065236273,'learning_rate_3':164.29004630496442}

rmse_antm_hl_u_lr = {'learning_rate_1':0.03129032055995892,'learning_rate_2':0.3950678494850448,'learning_rate_3':0.3596055408647369}

r2_antm_hl_u_lr = {'learning_rate_1':0.9717693376234477,'learning_rate_2':-418.77423100391877,'learning_rate_3':-153420.0328864784}

# %% [markdown]
# ## ASII

# %%
mae_asii_hl_u_lr = {'learning_rate_1':0.014984484662728566,'learning_rate_2':0.014862743641934127,'learning_rate_3':0.01738613382173947}

mape_asii_hl_u_lr = {'learning_rate_1':0.03391435204325115,'learning_rate_2':0.03366923393004505,'learning_rate_3':0.038148205286427365}

rmse_asii_hl_u_lr = {'learning_rate_1':0.020020778403811657,'learning_rate_2':0.020030782988198177,'learning_rate_3':0.022448203110551682}

r2_asii_hl_u_lr = {'learning_rate_1':0.9898421710809194,'learning_rate_2':0.9899428156740873,'learning_rate_3':0.9873040707733628}

# %% [markdown]
# ## ICBP

# %%
mae_icbp_hl_u_lr = {'learning_rate_1':0.019869628638565638,'learning_rate_2':0.007375501048888308,'learning_rate_3':0.2481420855985792}

mape_icbp_hl_u_lr = {'learning_rate_1':0.09147425780397894,'learning_rate_2':0.03500379616597862,'learning_rate_3':0.46248184707493295}

rmse_icbp_hl_u_lr = {'learning_rate_1':0.022785472568212693,'learning_rate_2':0.01093223587971163,'learning_rate_3':0.29176919267515794}

r2_icbp_hl_u_lr = {'learning_rate_1':0.9930787205901155,'learning_rate_2':0.9984805983751265,'learning_rate_3':-10130060349.416784}

# %% [markdown]
# ## JSMR

# %%
mae_jsmr_hl_u_lr = {'learning_rate_1':0.1747876878015338,'learning_rate_2':0.01167398550338823,'learning_rate_3':0.17217571334708587}

mape_jsmr_hl_u_lr = {'learning_rate_1':0.3206406132333469,'learning_rate_2':0.02903799041381432,'learning_rate_3':0.28529146356206614}

rmse_jsmr_hl_u_lr = {'learning_rate_1':0.21602432648161068,'learning_rate_2':0.016833908267642025,'learning_rate_3':0.2175438915947297}

r2_jsmr_hl_u_lr = {'learning_rate_1':0.0,'learning_rate_2':0.9938298320044374,'learning_rate_3':-13320900317009.041}

# %% [markdown]
# # EPOCH

# %% [markdown]
# ## ANTM

# %%
mae_antm_hl_u_lr_e = {'epoch_100':0.14754789239237595,'epoch_150':0.012603131954268052,'epoch_200':0.010756083597232485}

mape_antm_hl_u_lr_e = {'epoch_100':0.7403797531482074,'epoch_150':0.07157605810937363,'epoch_200':0.047077413811716186}

rmse_antm_hl_u_lr_e = {'epoch_100':0.22154097275102877,'epoch_150':0.017055567313677432,'epoch_200':0.014875900820590184}

r2_antm_hl_u_lr_e = {'epoch_100':-221038482894204.16,'epoch_150':0.9924575065041806,'epoch_200':0.9944954731854885}

# %% [markdown]
# ## ASII

# %%
mae_asii_hl_u_lr_e = {'epoch_100':0.014796198288149291,'epoch_150':0.014720629079311317,'epoch_200':0.015531000751860619}

mape_asii_hl_u_lr_e = {'epoch_100':0.03252959845439422,'epoch_150':0.03349409492304816,'epoch_200':0.03368880365631896}

rmse_asii_hl_u_lr_e = {'epoch_100':0.019880899176690187,'epoch_150':0.019787171074738395,'epoch_200':0.020626043608880918}

r2_asii_hl_u_lr_e = {'epoch_100':0.9900005761927053,'epoch_150':0.9900421439449422,'epoch_200':0.9889763587181039}

# %% [markdown]
# ## ICBP

# %%
mae_icbp_hl_u_lr_e = {'epoch_100':0.011829416279720813,'epoch_150':0.00863103057045081,'epoch_200':0.007548246517585376}

mape_icbp_hl_u_lr_e = {'epoch_100':0.05391095328713023,'epoch_150':0.044077354469535264,'epoch_200':0.02786548272161317}

rmse_icbp_hl_u_lr_e = {'epoch_100':0.015309465075169035,'epoch_150':0.012175448247557782,'epoch_200':0.011187546983256878}

r2_icbp_hl_u_lr_e = {'epoch_100':0.9969111260811065,'epoch_150':0.9980756743822062,'epoch_200':0.9984169773841658}

# %% [markdown]
# ## JSMR

# %%
mae_jsmr_hl_u_lr_e = {'epoch_100':0.018119861212689825,'epoch_150':0.012107913609979913,'epoch_200':0.012089393602446269}

mape_jsmr_hl_u_lr_e = {'epoch_100':0.043781076594289176,'epoch_150':0.03172246383620455,'epoch_200':0.029906221177962093}

rmse_jsmr_hl_u_lr_e = {'epoch_100':0.022323166047446056,'epoch_150':0.016932659020940932,'epoch_200':0.016973096009955235}

r2_jsmr_hl_u_lr_e = {'epoch_100':0.9894752418624992,'epoch_150':0.9937337140250488,'epoch_200':0.9937688105739413}

# %% [markdown]
# # BATCH SIZE

# %% [markdown]
# ## ANTM

# %%
mae_antm_hl_u_lr_ep = {'batch_size_32':0.012488533145321043,'batch_size_16':0.01294259904090866,'batch_size_8': 0.01507653190057723}

mape_antm_hl_u_lr_ep = {'batch_size_32':0.01666907824200452,'batch_size_16':0.018235288320124676,'batch_size_8':0.019064418329882173}

rmse_antm_hl_u_lr_ep = {'batch_size_32':0.06780591780945283,'batch_size_16':0.08227245690492796,'batch_size_8':2.640310693804523}

r2_antm_hl_u_lr_ep = {'batch_size_32':0.9927547014825319,'batch_size_16':0.9926595925838604,'batch_size_8':0.9916395348442628}

# %% [markdown]
# ## ASII

# %%
mae_asii_hl_u_lr_ep = {'batch_size_32':0.016920856064242262,'batch_size_16':0.017254665063887373,'batch_size_8':0.015346604139969425}

mape_asii_hl_u_lr_ep = {'batch_size_32':0.03633563979389126,'batch_size_16':0.04013173821403081,'batch_size_8':0.033018683195921786}

rmse_asii_hl_u_lr_ep = {'batch_size_32':0.022011401288948202,'batch_size_16':0.021790129419086132,'batch_size_8':0.02020180579718549}

r2_asii_hl_u_lr_ep = {'batch_size_32':0.9874077270736897,'batch_size_16':0.9879353116214824,'batch_size_8':0.9900479608200057}

# %% [markdown]
# ## ICBP

# %%
mae_icbp_hl_u_lr_ep = {'batch_size_32':0.007353329179454687,'batch_size_16':0.007274663427842254,'batch_size_8':0.014329047331934453}

mape_icbp_hl_u_lr_ep = {'batch_size_32':0.02843190299760299,'batch_size_16':0.0277478888285619,'batch_size_8':0.06350116606387053}

rmse_icbp_hl_u_lr_ep = {'batch_size_32':0.01201080759215415,'batch_size_16':0.011995981801348952,'batch_size_8':0.018692824157166034}

r2_icbp_hl_u_lr_ep = {'batch_size_32':0.9981393854996866,'batch_size_16':0.9981533501318129,'batch_size_8':0.9953377625240442}

# %% [markdown]
# ## JSMR

# %%
mae_jsmr_hl_u_lr_ep = {'batch_size_32':0.017781660946700365,'batch_size_16':0.011454908625903459,'batch_size_8':0.011488508080148499}

mape_jsmr_hl_u_lr_ep = {'batch_size_32':0.057102426873167404,'batch_size_16':0.028470031941793497,'batch_size_8':0.029825446451819868}

rmse_jsmr_hl_u_lr_ep = {'batch_size_32':0.02244715803377186,'batch_size_16':0.016602562556061077,'batch_size_8':0.01656066385999743}

r2_jsmr_hl_u_lr_ep = {'batch_size_32':0.9887229545556224,'batch_size_16':0.9940081988547483,'batch_size_8':0.9939849099075261}
