# %%
import matplotlib.pyplot as plt

# %%
Arima_MAE = [36.0, 109.48,128.83,90.16]
LSTM64_50_MAE_32 = [35.63,106.42,128.06,76.66]
LSTM64_100_MAE_32 = [32.09,97.39,176.05,76.04]
LSTM64_50_MAE_16 = [32.28,99.05,172.62,76.35]
LSTM64_100_MAE_16= [31.99,97.77,123.95,75.99]
LSTM64_50_MAE_8 = [55.48, 101.12, 107.76,76.65]
LSTM64_100_MAE_8 = [31.69, 96.72, 117.17,76.71]


Arima_RMSE = [61.06,142.63,184.73,119.96]
LSTM64_50_RMSE_32 = [65.50,140.11,185.11,103.87]
LSTM64_100_RMSE_32 = [57.66,129.28,252.66,103.82]
LSTM64_50_RMSE_16 = [58.03,130.63,240.37,103.75]
LSTM64_100_RMSE_16= [57.33,129.51,180.40,103.78]
LSTM64_50_RMSE_8 = [103.62, 132.30,164.59,104.13]
LSTM64_100_RMSE_8 = [57.33,128.95,173.83,104.27]

Arima_R2 = [0.99,0.99,0.98,0.98]
LSTM64_50_R2_32 = [0.99,0.98,0.97,0.98]
LSTM64_100_R2_32 = [0.99,0.99,0.95,0.98]
LSTM64_50_R2_16 = [0.99,0.99,0.95,0.98]
LSTM64_100_R2_16= [0.99,0.99,0.97,0.98]
LSTM64_50_R2_8 = [0.98,0.99,0.98,0.98]
LSTM64_100_R2_8 = [0.99,0.99,0.97,0.98]

# %%
data1 = [Arima_RMSE, LSTM64_50_RMSE_32, LSTM64_100_RMSE_32,LSTM64_50_RMSE_16, LSTM64_100_RMSE_16,LSTM64_50_RMSE_8, LSTM64_100_RMSE_8]
data2 = [Arima_MAE, LSTM64_50_MAE_32, LSTM64_100_MAE_32,LSTM64_50_MAE_32, LSTM64_100_MAE_32,LSTM64_50_MAE_32, LSTM64_100_MAE_32]
plt.boxplot(data1, patch_artist=True)
plt.xticks([1, 2, 3,4,5,6,7], ['Arima', 'LSTM 64_50_32', 'LSTM 64_100_32','LSTM 64_50_16', 'LSTM 64_100_16','LSTM 64_50_8', 'LSTM 64_100_8'])

# giving a title to my graph
plt.title('RMSE PLOT')
# plt.savefig('boxplot_rmse')
 
# function to show the plot
plt.show()

# %%
data1 = [Arima_RMSE, LSTM64_50_RMSE_32, LSTM64_100_RMSE_32,LSTM64_50_RMSE_16, LSTM64_100_RMSE_16,LSTM64_50_RMSE_8, LSTM64_100_RMSE_8]
data2 = [Arima_MAE, LSTM64_50_MAE_32, LSTM64_100_MAE_32,LSTM64_50_MAE_32, LSTM64_100_MAE_32,LSTM64_50_MAE_32, LSTM64_100_MAE_32]
data3 =[Arima_R2, LSTM64_50_R2_32, LSTM64_100_R2_32,LSTM64_50_R2_32, LSTM64_100_R2_32,LSTM64_50_R2_32, LSTM64_100_R2_32]
# plot baseline and predictions
fig, ax = plt.subplots(figsize=(16,9))
ax.boxplot(data2, patch_artist=True)
ax.set_title('Boxplot MAE Model ARIMA dan LSTM')
# ax.set_xlabel('Date',fontsize=15)
ax.set_xticks([1, 2, 3,4,5,6,7],['Arima', 'LSTM 64_50_32', 'LSTM 64_100_32','LSTM 64_50_16', 'LSTM 64_100_16','LSTM 64_50_8', 'LSTM 64_100_8'])
plt.savefig("boxplot_MAE_lstm")

plt.show()
